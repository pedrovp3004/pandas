# %%
import pandas as pd 

#Arquivo de Vendas
vendasDF = pd.read_excel("..//dados//Vendas_Merge.xlsx")

#Arquivo de Vendedores
vendedoresDF = pd.read_excel("..//dados//Vendedores_Merge.xlsx")

#Arquivo de Produtos
produtosDF = pd.read_excel("..//dados//Produtos_Merge.xlsx")

display(produtosDF)
# Out:
#     ID Produto                        Produto  Valor Unitário
# 0       100212              Bermuda Masculino          148.56
# 1       100411              Bolsa de Trabalho          248.73
# 2       100301                 Bota Masculina          224.14
# 3       100208                Calça Bailarina           46.90
# 4       100359          Calça Feminina Jogger           69.99
# 5       100105               Camisa Masculina          153.40
# 6       100244  Camisa Masculina Festa Balada          146.14
# 7       100226                 Camisa Térmica           41.90
# 8       100001                 Colar Pingente           89.90
# 9       100345        Jaqueta Masculina Preta          150.50
# 10      100128    Kit de Pinceis de Maquiagem          116.52
# 11      100443               Sapatilha Sapato           55.90
# 12      100128                  Sapato Social           81.90
# 13      100482                 Tênis Feminino           89.99
# ...

# %%
import pandas as pd 

#Arquivo de Vendas
vendasDF = pd.read_excel("..//dados//Vendas_Merge.xlsx")

#Arquivo de Vendedores
vendedoresDF = pd.read_excel("..//dados//Vendedores_Merge.xlsx")

#Arquivo de Produtos
produtosDF = pd.read_excel("..//dados//Produtos_Merge.xlsx")

vendasDF = vendasDF.merge(vendedoresDF)

display(vendasDF)
# Out:
#     Id Vendedor  ID Produto Data Venda  Quantidade Vendida  Valor Unitário  \
# 0         27264      100482 2023-01-01                   8           89.99
# 1         21732      100359 2023-01-02                   2           69.99
# 2         27082      100105 2023-01-03                   2          153.40
# 3         22936      100212 2023-01-04                  10          148.56
# 4         21164      100244 2023-01-05                   6          146.14
# 5         28824      100301 2023-01-06                   2          224.14
# 6         27264      100345 2023-01-07                   4          150.50
# 7         21732      100411 2023-01-08                   4          248.73
# 8         27082      100128 2023-01-09                   9          116.52
# 9         22936      100877 2023-01-10                   1           59.90
# 10        27264      100208 2023-01-11                   6           46.90
# ...

# %%
import pandas as pd 

#Arquivo de Vendas
vendasDF = pd.read_excel("..//dados//Vendas_Merge.xlsx")

#Arquivo de Produtos
produtosDF = pd.read_excel("..//dados//Produtos_Merge.xlsx")

#Unindo a tabela de Vendas com a tabela de Produtos
#Através da coluna de 'ID Produto' e 'Valor Unitário'

vendasDF = vendasDF.merge(produtosDF, on = ["ID Produto", "Valor Unitário"])

display(vendasDF)
# Out:
#     Id Vendedor  ID Produto Data Venda  Quantidade Vendida  Valor Unitário  \
# 0         27264      100482 2023-01-01                   8           89.99
# 1         21732      100359 2023-01-02                   2           69.99
# 2         27082      100105 2023-01-03                   2          153.40
# 3         22936      100212 2023-01-04                  10          148.56
# 4         21164      100244 2023-01-05                   6          146.14
# 5         28824      100301 2023-01-06                   2          224.14
# 6         27264      100345 2023-01-07                   4          150.50
# 7         21732      100411 2023-01-08                   4          248.73
# 8         27082      100128 2023-01-09                   9          116.52
# 9         22936      100877 2023-01-10                   1           59.90
# 10        27264      100208 2023-01-11                   6           46.90
# ...

# %%
import pandas as pd 

#Arquivo de Vendas
vendasDF = pd.read_excel("..//dados//Vendas_Merge.xlsx")

#Arquivo de Vendedores
vendedoresDF = pd.read_excel("..//dados//Vendedores_Merge.xlsx")

#Arquivo de Produtos
produtosDF = pd.read_excel("..//dados//Produtos_Merge.xlsx")

vendasDF = vendasDF.merge(produtosDF)

vendasDF = vendasDF.merge(vendedoresDF)

display(vendasDF)
# Out:
#     Id Vendedor  ID Produto Data Venda  Quantidade Vendida  Valor Unitário  \
# 0         27264      100482 2023-01-01                   8           89.99
# 1         21732      100359 2023-01-02                   2           69.99
# 2         27082      100105 2023-01-03                   2          153.40
# 3         22936      100212 2023-01-04                  10          148.56
# 4         21164      100244 2023-01-05                   6          146.14
# 5         28824      100301 2023-01-06                   2          224.14
# 6         27264      100345 2023-01-07                   4          150.50
# 7         21732      100411 2023-01-08                   4          248.73
# 8         27082      100128 2023-01-09                   9          116.52
# 9         22936      100877 2023-01-10                   1           59.90
# 10        27264      100208 2023-01-11                   6           46.90
# ...
